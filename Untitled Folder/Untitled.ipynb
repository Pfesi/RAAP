# %%
import numpy as np

# %%
# in arcminutes
lam=0.025 #2.5cm
D=26 #m
(np.rad2deg(lam/D))*60
# Out:
# 3.305525741139365

# %%
lam=0.06 #6cm
D=100 #m
(np.rad2deg(lam/D))*60
# Out:
# 2.0626480624709633

# %%
# eye
lam=600*1e-9 #
D=1*1e-3 #m
(np.rad2deg(lam/D))*60
# Out:
# 2.0626480624709638

# %%
# eye
lam=0.025 #
B=200*1e3 #m
(np.rad2deg(lam/D))*60*60
# Out:
# 5156620.156177409
